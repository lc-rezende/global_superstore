# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.style.use('fivethirtyeight')

# %%
df = pd.read_excel('data/global_superstore.xls')

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# # Quais são os produtos mais lucrativos?

# %%
df_profitable = df.groupby('Product ID').sum()

# %%
df_profitable = df_profitable.loc[:,['Profit']]

# %% [markdown]
# ### Top 10 produtos mais lucrativos

# %%
df_profitable.sort_values(by='Profit', ascending=False).head(10).plot(kind='bar')

# %% [markdown]
# ### Top 10 produtos menos lucrativos

# %%
df_profitable.sort_values(by='Profit').head(10).plot(kind='bar')

# %% [markdown]
# # Quais são os cliente mais lucrativos?

# %%
df_profitableCustomers = df.groupby('Customer ID').sum()

# %%
df_profitableCustomers = df_profitableCustomers.loc[:,['Profit']]

# %%
df_profitableCustomers.head()
# Out:
#                  Profit
# Customer ID
# AA-10315      447.69050
# AA-10375      677.47740
# AA-10480     1516.47518
# AA-10645     3051.43900
# AA-315        535.56600

# %%
df_profitable.head()
# Out:
#                    Profit
# Product ID
# FUR-ADV-10000002   60.390
# FUR-ADV-10000108    3.360
# FUR-ADV-10000183 -651.738
# FUR-ADV-10000188    4.200
# FUR-ADV-10000190  104.460

# %% [markdown]
# ### Top 10 clientes mais lucrativos

# %%
df_profitableCustomers.sort_values(by='Profit', ascending=False).head(10).plot(kind='bar')

# %% [markdown]
# ### Top 10 clientes menos lucrativos

# %%
df_profitableCustomers.sort_values(by='Profit').head(10).plot(kind='bar')

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df_profitableCountries = df.groupby(['Country']).sum()

# %%
df_profitableCountries.head()
# Out:
#               Row ID  Postal Code        Sales  Quantity  Discount  \
# Country
# Afghanistan  1446606          0.0  21673.32000       228     0.000
# Albania       750891          0.0   3888.12000        40     0.000
# Algeria      9148550          0.0  36091.59000       454     0.000
# Angola       5671843          0.0  25554.00000       317     0.000
# Argentina    1825545          0.0  57511.78328      1504   168.952
#
#                   Profit  Shipping Cost
# Country
# Afghanistan   5460.30000       2300.230
# Albania        709.32000        698.570
# Algeria       9106.50000       3726.410
# Angola        6494.97000       2418.400
# Argentina   -18693.79672       6366.362

# %%
df_profitableCountries.drop(labels=['Row ID', 'Postal Code'], inplace=True, axis=1)

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df_profitableCountries, kind="reg")

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x=df['Discount'], y=df['Profit'], data=df, kind='scatter')

# %% [markdown]
# ## Timeseries Forecasting

# %%
df.sort_values(by='Order Date', inplace=True)

# %%
df2 = df.groupby([df['Order Date']])['Sales'].sum()

# %%
df2.head()
# Out:
# Order Date
# 2011-01-01     808.56300
# 2011-01-02     314.22000
# 2011-01-03    4503.53720
# 2011-01-04    2808.87024
# 2011-01-05    3662.31000
# Name: Sales, dtype: float64

# %%
df2.to_frame()
df2 = df2.reset_index()

# %%
df2.head()
# Out:
#   Order Date       Sales
# 0 2011-01-01   808.56300
# 1 2011-01-02   314.22000
# 2 2011-01-03  4503.53720
# 3 2011-01-04  2808.87024
# 4 2011-01-05  3662.31000

# %%
df2.rename(columns={'Order Date': 'ds', 'Sales': 'y'}, inplace=True)
df2['y'] = np.log(df2['y'])

# %%
from fbprophet import Prophet
from fbprophet.diagnostics import cross_validation

# %%
m = Prophet()
m.fit(df2)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 1790 2015-12-27
# 1791 2015-12-28
# 1792 2015-12-29
# 1793 2015-12-30
# 1794 2015-12-31

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 1790 2015-12-27   7.444235    6.592132    8.314124
# 1791 2015-12-28  10.173061    9.347115   11.078220
# 1792 2015-12-29  10.112680    9.219585   11.004226
# 1793 2015-12-30  10.036999    9.163117   10.943108
# 1794 2015-12-31   9.992138    9.107928   10.827093

# %%
fig1 = m.plot(forecast)

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    '''Take in true and predicted values and calculate the MAPE score'''
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# %time
cv_results = cross_validation(m, horizon='120 days')
# Out:
# INFO:fbprophet:Making 17 forecasts with cutoffs between 2012-01-16 00:00:00 and 2014-09-02 00:00:00
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs

# %%
# %time
mape_baseline = mean_absolute_percentage_error(cv_results.y, cv_results.yhat)
print(mape_baseline)
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.3 µs
# 6.367181687172042
